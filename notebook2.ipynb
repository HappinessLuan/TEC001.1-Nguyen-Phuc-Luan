# %%
print("luan")
# Out:
# luan

# %%
a = 100
b = 200
c = 300
print('a, b, c')
print('luan')
# Out:
# a, b, c
# luan

# %%
print('luan')
# Out:
# luan

# %%
print('nguyễn, phúc, luân,' sep = '##')
# Out:
#   Cell In[13], line 1
#     print('nguyễn, phúc, luân,' sep = '##')
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print('nguyễn', 'phúc', 'luân', sep = '##')
# Out:
# nguyễn##phúc##luân

# %%
print('nguyễn', 'phúc', 'luân', sep = '--', end ='!\n')
print('tên là luân')
# Out:
# nguyễn--phúc--luân!
# tên là luân

# %%
#tao tên luân
print('nguyễn fuck luân')
# Out:
# nguyễn fuck luân

# %%
'''vờ cờ lờ tên luân à
adu tên luân à
đá bóng không luân
'''
print('ok chiều nay 5r đá')
# Out:
# ok chiều nay 5r đá

# %%
a = 100
print(type(a))
# Out:
# <class 'int'>

# %%
a = 100
A = 110
dientich = 120
dienTich=130
print('a, A, dientich, dienTich')
# Out:
# a, A, dientich, dienTich

# %%
a = 100
b = 1.2
c = 2 + 1j
print(type(a), type(b), type(c), sep = '\n')
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
a=0b1001
print(a)
b=0o2011
print(b)
c=0x502F
print(c)
# Out:
# 9
# 1033
# 20527

# %%
 a = 28.0455
 print('%.3f' % a)
# Out:
# 28.046

# %%
a=1.234567
print(round(a,3))
# Out:
# 1.235

# %%
a=1.22267
print('{:.2f}'.format(a))
# Out:
# 1.22

# %%
a=3+5j
print(a.real, a.imag)
# Out:
# 3.0 5.0

# %%
a=True
print(type(a))
# Out:
# <class 'bool'>

# %%
a=False
print(type(a))
# Out:
# <class 'bool'>

# %%
a=1
b=0
c=luan
print(bool(a))
print(bool(b))
print(bool(c))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 3
#       1 a=1
#       2 b=0
# ----> 3 c=luan
#       4 print(bool(a))
#       5 print(bool(b))
#
# NameError: name 'luan' is not defined

# %%
print(bool(100))
# Out:
# True

# %%
a=100
print(bool(a))
b=('')
print(bool(b))
# Out:
# True
# False

# %%
a='''100
200'''
print(a)
print(type(a))
# Out:
# 100
# 200
# <class 'str'>

# %%
a=int(123)
b=int('123')
c=int(123.123)
print(a,b,c)
# Out:
# 123 123 123

# %%
a=123.590
b=int(a)
print(b)
# Out:
# 123

# %%
a=100
b=a
print(a,b)
# Out:
# 100 100

# %%
a, b, c = 100, 200, 300
print(a,b,c)
# Out:
# 100 200 300

# %%
a=100
b=200
a,b=b,a
print(a,b)
# Out:
# 200 100

# %%
a=100
b=200
c=a+b
d=a/b
e=a%b
print(c,d,e)
# Out:
# 300 0.5 100

# %%
print(100!=200)
# Out:
# True

# %%
print(200==200 and 1<0)
# Out:
# False

# %%
a=(1,2,3)
b=(1,2,3)
print(a is b)
# Out:
# False

# %%
a=('nguyễn phúc luân có ô tô, xe máy, xe đạp')
print('máy bay'in a)
# Out:
# False

# %%
s=input('hãy nhập con số bất kỳ:')
print('s')
# Out:
# s

# %%
s=input('nhập số bất kì:')
print('S')
# Out:
# S

# %%
s=input('nhap 1 so nguyen')
print(s)
# Out:
# 100

# %%
a=int(input('nhập chiều rộng:'))
b=int(input('nhập chiều dài:'))
chuvi=2*(a+b)
dientich=a*b
print(chuvi,dientich)
# Out:
# 10 6

# %%
s=input("nhập 3 số:")
a=s.split()
x,y,z=map(int,a)
print(x+y+z)
# Out:
# 600

# %%
x,y,z,n=map(int,input('nhap 4 số nguyên:').split())
print(x+y*z/3)
# Out:
# 6.0
